# %%
import pandas as pd

# %%
sd=pd.read_csv(r"E:\Uddanous\07 Feb\hotel_booking_data.csv")

# %%
sd.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2022               July
# 1  Resort Hotel            0        737               2022               July
# 2  Resort Hotel            0          7               2022               July
# 3  Resort Hotel            0         13               2022               July
# 4  Resort Hotel            0         14               2022               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...   adr  \
# 0                        0                     0       2  ...   0.0
# 1                        0                     0       2  ...   0.0
# 2                        0                     1       1  ...  75.0
# 3                        0                     1       1  ...  75.0
# 4                        0                     2       2  ...  98.0
#
#    required_car_parking_spaces total_of_special_requests reservation_status  \
# 0                            0                         0          Check-Out
# 1                            0                         0          Check-Out
# 2                            0                         0          Check-Out
# 3                            0                         0          Check-Out
# 4                            0                         1          Check-Out
#
#   reservation_status_date            name                        email  \
# 0              01-07-2022   Ernest Barnes  Ernest.Barnes31@outlook.com
# 1              01-07-2022    Andrea Baker       Andrea_Baker94@aol.com
# 2              02-07-2022  Rebecca Parker   Rebecca_Parker@comcast.net
# 3              02-07-2022    Laura Murray            Laura_M@gmail.com
# 4              03-07-2022     Linda Hines           LHines@verizon.com
#
#    phone-number       credit_card Unnamed: 36
# 0  669-792-1661  ************4322         NaN
# 1  858-637-6955  ************9157         NaN
# 2  652-885-2745  ************3734         NaN
# 3  364-656-8427  ************5677         NaN
# 4  713-226-5883  ************5498         NaN
#
# [5 rows x 37 columns]

# %%
sd.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# agent                              16340
# company                           112593
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# reservation_status_date                0
# name                                   0
# email                                  0
# phone-number                           0
# credit_card                            0
# Unnamed: 36                       119390
# dtype: int64

# %%
sd.drop(columns=['name', 'email', 'phone-number', 'credit_card', 'Unnamed: 36'], errors='ignore', inplace=True)

# %%
sd['children'].fillna(0, inplace=True)

# %%
sd['country'].fillna("unknown", inplace=True)

# %%
sd['agent'].fillna("unknown", inplace=True)

# %%
sd['company'].fillna("unknown", inplace=True)

# %%
sd.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# required_car_parking_spaces       0
# total_of_special_requests         0
# reservation_status                0
# reservation_status_date           0
# dtype: int64

# %%
sd['children'] = sd['children'].astype(int)

# %%
sd.to_csv("cleaned_hotel_booking_data.csv", index=False)

# %%
sd['agent'] = sd['agent'].replace("unknown", np.nan)

# %%
sd['agent'] = pd.to_numeric(sd['agent'], errors='coerce')

# %%
sd['agent'].fillna(0, inplace=True)

# %%
sd['agent'].dtype, sd['agent'].isnull().sum()
# Out:
# (dtype('float64'), 0)

# %%
sd.to_csv("cleaned_hotel_booking_data.csv", index=False)

# %% [markdown]
# # Create a New Column: "Desired or Non-Desired Booking"

# %%
sd['booking_status'] = sd['is_canceled'].apply(lambda x: 'Desired' if x == 0 else 'Non-Desired')

# %%
sd.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2022               July
# 1  Resort Hotel            0        737               2022               July
# 2  Resort Hotel            0          7               2022               July
# 3  Resort Hotel            0         13               2022               July
# 4  Resort Hotel            0         14               2022               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  agent  company  \
# 0                        0                     0       2  ...    0.0  unknown
# 1                        0                     0       2  ...    0.0  unknown
# 2                        0                     1       1  ...    0.0  unknown
# 3                        0                     1       1  ...  304.0  unknown
# 4                        0                     2       2  ...  240.0  unknown
#
#   days_in_waiting_list customer_type   adr required_car_parking_spaces  \
# 0                    0     Transient   0.0                           0
# 1                    0     Transient   0.0                           0
# 2                    0     Transient  75.0                           0
# 3                    0     Transient  75.0                           0
# 4                    0     Transient  98.0                           0
#
#    total_of_special_requests  reservation_status  reservation_status_date  \
# 0                          0           Check-Out               01-07-2022
# 1                          0           Check-Out               01-07-2022
# 2                          0           Check-Out               02-07-2022
# 3                          0           Check-Out               02-07-2022
# 4                          1           Check-Out               03-07-2022
#
#   booking_status
# 0        Desired
# 1        Desired
# 2        Desired
# 3        Desired
# 4        Desired
#
# [5 rows x 33 columns]

# %% [markdown]
# # Check Who Cancels More: Family, Couple, Friends, or Single Guests

# %%
def categorize_guests(row):
    if row['adults'] == 2 and row['children'] == 0 and row['babies'] == 0:
        return 'Couple'
    elif row['children'] > 0 or row['babies'] > 0:
        return 'Family'
    elif row['adults'] == 1:
        return 'Single'
    elif row['adults'] > 2 and row['children'] == 0 and row['babies'] == 0:
        return 'Friends/Group'
    else:
        return 'Other'

sd['guest_category'] = sd.apply(categorize_guests, axis=1)

# %%
sd.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2022               July
# 1  Resort Hotel            0        737               2022               July
# 2  Resort Hotel            0          7               2022               July
# 3  Resort Hotel            0         13               2022               July
# 4  Resort Hotel            0         14               2022               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  company  \
# 0                        0                     0       2  ...  unknown
# 1                        0                     0       2  ...  unknown
# 2                        0                     1       1  ...  unknown
# 3                        0                     1       1  ...  unknown
# 4                        0                     2       2  ...  unknown
#
#    days_in_waiting_list customer_type   adr required_car_parking_spaces  \
# 0                     0     Transient   0.0                           0
# 1                     0     Transient   0.0                           0
# 2                     0     Transient  75.0                           0
# 3                     0     Transient  75.0                           0
# 4                     0     Transient  98.0                           0
#
#   total_of_special_requests  reservation_status  reservation_status_date  \
# 0                         0           Check-Out               01-07-2022
# 1                         0           Check-Out               01-07-2022
# 2                         0           Check-Out               02-07-2022
# 3                         0           Check-Out               02-07-2022
# 4                         1           Check-Out               03-07-2022
#
#    booking_status guest_category
# 0         Desired         Couple
# 1         Desired         Couple
# 2         Desired         Single
# 3         Desired         Single
# 4         Desired         Couple
#
# [5 rows x 34 columns]

# %%
sd.to_csv("cleaned_hotel_booking_data1.csv", index=False)
